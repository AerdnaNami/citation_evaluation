# %%
import re
from collections import defaultdict
from typing import List, Tuple, Dict, Any, Optional

def tokenize_with_offsets(text: str) -> Tuple[List[str], List[Tuple[int, int]]]:
    """
    Simple whitespace tokenizer that also returns character offsets for each token.
    Returns (tokens, [(start,end), ...])
    """
    tokens = []
    offsets = []
    for match in re.finditer(r"\S+", text):
        tokens.append(match.group())
        offsets.append((match.start(), match.end()))
    return tokens, offsets

def _token_overlaps(tok_start: int, tok_end: int, span_start: int, span_end: int) -> bool:
    return not (tok_end <= span_start or tok_start >= span_end)

def _find_span_occurrence(document_text: str, span_text: str, used_starts: set) -> Tuple[int, int]:
    """
    Find a span_text occurrence in document_text that hasn't been used yet (by start index).
    Returns (start, end) or (-1, -1).
    """
    if not span_text:
        return -1, -1

    start = document_text.find(span_text)
    while start != -1:
        if start not in used_starts:
            end = start + len(span_text)
            return start, end
        start = document_text.find(span_text, start + 1)

    return -1, -1

def _normalize_spans_for_document(item: Dict[str, Any], document_text: str) -> List[Tuple[int, int]]:
    """
    Supports BOTH formats:
    (A) Per-document format:
        {
          "document": "...",
          "spans": [
              {"span": "...", "start": 10, "end": 20},
              {"span": "..."}  # start/end optional
              "..."            # string spans also supported
          ]
        }

    (B) Per-span format:
        {"document": "...", "span": "...", "start": ..., "end": ...}
    """
    normalized: List[Tuple[int, int]] = []
    used_starts = set()

    # --------
    # Format A: per-document object with "spans"
    # --------
    if "spans" in item and isinstance(item["spans"], list):
        for s in item["spans"]:
            s_start: Optional[int] = None
            s_end: Optional[int] = None

            # span entry as dict
            if isinstance(s, dict):
                # prefer explicit offsets if valid
                if "start" in s and "end" in s:
                    try:
                        s_start = int(s["start"])
                        s_end = int(s["end"])
                    except Exception:
                        s_start, s_end = None, None

                # if missing/invalid offsets, fall back to matching span text
                if s_start is None or s_end is None or s_start >= s_end:
                    span_text = s.get("span") or s.get("text") or s.get("span_text")
                    if isinstance(span_text, str) and span_text.strip():
                        s_start, s_end = _find_span_occurrence(document_text, span_text, used_starts)

            # span entry as string
            elif isinstance(s, str) and s.strip():
                s_start, s_end = _find_span_occurrence(document_text, s, used_starts)

            # validate + clamp
            if s_start is None or s_end is None:
                continue
            s_start = max(0, min(len(document_text), s_start))
            s_end = max(0, min(len(document_text), s_end))
            if s_start >= s_end:
                continue

            used_starts.add(s_start)
            normalized.append((s_start, s_end))

        return normalized

    # --------
    # Format B: per-span object (legacy)
    # --------
    try:
        s_start = int(item.get("start"))
        s_end = int(item.get("end"))
    except Exception:
        s_start, s_end = None, None

    if s_start is None or s_end is None or s_start >= s_end:
        span_text = item.get("span") or item.get("text") or item.get("span_text")
        if isinstance(span_text, str) and span_text.strip():
            s_start, s_end = _find_span_occurrence(document_text, span_text, used_starts)

    if s_start is None or s_end is None:
        return []

    s_start = max(0, min(len(document_text), s_start))
    s_end = max(0, min(len(document_text), s_end))
    if s_start >= s_end:
        return []

    return [(s_start, s_end)]

def convert_to_ner_format(span_data: List[dict], label: str) -> List[dict]:
    """
    Accepts either:
      - list of per-document items with {"document":..., "spans":[...]}
      - list of per-span items with {"document":..., "span":..., "start":..., "end":...}
    Produces: [{"tokens":[...], "labels":[...]}] one per unique document text.
    """
    docs = defaultdict(list)

    # Group items by document text (works for both formats)
    for item in span_data:
        if not isinstance(item, dict):
            continue
        doc_text = item.get("document") or item.get("full_text") or item.get("text")
        if not isinstance(doc_text, str) or not doc_text.strip():
            continue
        docs[doc_text].append(item)

    ner_examples = []
    label_name = label.replace(" ", "_")

    for document_text, items_for_doc in docs.items():
        tokens, offsets = tokenize_with_offsets(document_text)
        labels = ["O"] * len(tokens)

        # Collect all spans for this doc (support multiple items per doc, and/or per-document items)
        all_spans: List[Tuple[int, int]] = []
        for it in items_for_doc:
            all_spans.extend(_normalize_spans_for_document(it, document_text))

        # sort spans by start so we process left-to-right
        all_spans.sort(key=lambda x: (x[0], x[1]))

        # Apply BIO labels
        for span_start, span_end in all_spans:
            inside = False
            for i, (tok_start, tok_end) in enumerate(offsets):
                if not _token_overlaps(tok_start, tok_end, span_start, span_end):
                    if inside:
                        inside = False
                    continue

                # token overlaps the span
                if labels[i] == "O":
                    if not inside:
                        labels[i] = f"B-{label_name}"
                        inside = True
                    else:
                        labels[i] = f"I-{label_name}"
                else:
                    # do not overwrite existing labels
                    if not inside:
                        inside = True

        ner_examples.append({"tokens": tokens, "labels": labels})

    return ner_examples

# %%
import json
from collections import defaultdict

categories = ['Unsupported claim', 'Format', 'Coherence', 'Lacks synthesis']

with open("../synthetic_sampling/samples/for_synth_sampling.json", 'r') as f:
    for_synth_data = json.load(f)

with open("../synthetic_sampling/samples/for_eval.json", 'r') as f:
    for_eval = json.load(f)

# Merge the two dicts safely (paper_id -> annotations)
total_data = {}
for d in (for_synth_data, for_eval):
    for k, v in d.items():
        if k not in total_data:
            total_data[k] = []
        total_data[k].extend(v)

# New grouped structure
grouped_total_data = {cat: [] for cat in categories}

for category in categories:

    # document_text -> list of span dicts
    docs = defaultdict(list)

    for paper_id, samples in total_data.items():
        for sample in samples:
            if sample.get('label') != category:
                continue

            document_text = sample.get('full_text')
            if not isinstance(document_text, str):
                continue

            docs[document_text].append({
                "span": sample.get("text"),
                "start": sample.get("start"),
                "end": sample.get("end"),
            })

    # Convert grouped dict to list format
    for doc_text, spans in docs.items():
        grouped_total_data[category].append({
            "document": doc_text,
            "spans": spans
        })

with open("../synthetic_sampling/samples/total_real_data.json", 'w') as f:
    json.dump(grouped_total_data, f, indent=2, ensure_ascii=False)

print("Saved grouped real data.")
# Out:
# Saved grouped real data.

# %% [markdown]
# ### To train with synthetic and evaluat on real:

# %%
import os 
import random 

synth_path = "../synthetic_sampling/samples/synthetic_samples_complete.json"
eval_path = "../synthetic_sampling/samples/total_real_data.json"

categories = {
    'Unsupported claim': 'unsupported_claim',
    'Lacks synthesis': "lacks_synthesis",
    'Coherence': "coherence",
    'Format': "format"
}

# train/dev split ratios
TRAIN_RATIO = 1
DEV_RATIO = 0.0
EVAL_RATIO = 0.0  # unused, eval comes from eval_path

os.makedirs("data", exist_ok=True)

with open(synth_path, "r", encoding="utf-8") as f:
    span_data_all = json.load(f)

with open(eval_path, "r") as f:
    eval_data_all = json.load(f)

for category in list(eval_data_all.keys()):
    for item in eval_data_all[category]:
        # Prefer an explicit 'document' key
        if 'full_text' in item and 'document' not in item:
            item['document'] = item['full_text']
            # keep original if you want; here we remove to be consistent
            del item['full_text']
        if 'text' in item and 'span' not in item:
            item['span'] = item['text']
            del item['text']
        # If eval entries have span char offsets but different names, try to unify
        if 'start' in item and 'end' in item:
            # nothing to do
            pass
        else:
            # try to salvage if eval uses 'span' string only: we'll leave that to convert_to_ner_format fallback
            pass

# For each category, convert and save
for category_display, out_dirname in categories.items():
    print(f"Processing category: {category_display}")

    # get synthetic entries for this category
    span_entries = span_data_all.get(category_display, [])
    if not isinstance(span_entries, list):
        print(f"Warning: expected list for synthetic entries of {category_display}, got {type(span_entries)}. Skipping.")
        continue

    ner_data = convert_to_ner_format(span_entries, category_display)

    # eval set
    eval_entries = eval_data_all.get(category_display, [])
    if not isinstance(eval_entries, list):
        eval_entries = []
    eval_ner_data = convert_to_ner_format(eval_entries, category_display)

    # Shuffle before splitting
    random.shuffle(ner_data)

    n = len(ner_data)
    n_train = int(n * TRAIN_RATIO)
    n_dev = int(n * DEV_RATIO)

    train_split = ner_data[:n_train]
    dev_split = ner_data[n_train:n_train + n_dev]
    eval_split = eval_ner_data 

    # ensure output dirs
    full_out_dir = os.path.join("data", out_dirname)
    os.makedirs(full_out_dir, exist_ok=True)

    train_path_out = os.path.join(full_out_dir, f"{out_dirname}_ner_train.json")
    dev_path_out = os.path.join(full_out_dir, f"{out_dirname}_ner_dev.json")
    eval_path_out = os.path.join(full_out_dir, f"{out_dirname}_ner_eval.json")

    with open(train_path_out, "w", encoding="utf-8") as f:
        json.dump(train_split, f, indent=2, ensure_ascii=False)

    with open(dev_path_out, "w", encoding="utf-8") as f:
        json.dump(dev_split, f, indent=2, ensure_ascii=False)

    with open(eval_path_out, "w", encoding="utf-8") as f:
        json.dump(eval_split, f, indent=2, ensure_ascii=False)

    # numbers shown are about documents and not spans
    print(f"Saved: train={len(train_split)} dev={len(dev_split)} eval={len(eval_split)} -> {full_out_dir}")
# Out:
# Processing category: Unsupported claim
# Saved: train=249 dev=0 eval=54 -> data/unsupported_claim
# Processing category: Lacks synthesis
# Saved: train=276 dev=0 eval=22 -> data/lacks_synthesis
# Processing category: Coherence
# Saved: train=299 dev=0 eval=19 -> data/coherence
# Processing category: Format
# Saved: train=295 dev=0 eval=22 -> data/format

# %% [markdown]
# ### To evaluate and train with synthetic:

# %%
import os
import json
import random

synth_path = "../synthetic_sampling/samples/synthetic_samples_complete.json"

categories = {
    'Unsupported claim': 'unsupported_claim',
    'Lacks synthesis': "lacks_synthesis",
    'Coherence': "coherence",
    'Format': "format"
}

# train/dev/eval split ratios (all from synthetic)
TRAIN_RATIO = 0.8
DEV_RATIO = 0.1
EVAL_RATIO = 0.1

os.makedirs("data", exist_ok=True)
random.seed(42)

with open(synth_path, "r", encoding="utf-8") as f:
    span_data_all = json.load(f) 

# For each category, convert and save
for category_display, out_dirname in categories.items():
    print(f"Processing category: {category_display}")

    # get synthetic entries for this category
    span_entries = span_data_all.get(category_display, [])
    if not isinstance(span_entries, list):
        print(f"Warning: expected list for synthetic entries of {category_display}, got {type(span_entries)}. Skipping.")
        continue

    # convert to NER (groups spans under same document inside the function)
    ner_data = convert_to_ner_format(span_entries, category_display)

    # Shuffle before splitting
    random.shuffle(ner_data)

    n = len(ner_data)
    n_train = int(n * TRAIN_RATIO)
    n_dev = int(n * DEV_RATIO)
    n_eval = n - n_train - n_dev  # remainder goes to eval

    train_split = ner_data[:n_train]
    dev_split = ner_data[n_train:n_train + n_dev]
    eval_split = ner_data[n_train + n_dev:]

    # ensure output dirs
    full_out_dir = os.path.join("data", out_dirname)
    os.makedirs(full_out_dir, exist_ok=True)

    train_path_out = os.path.join(full_out_dir, f"{out_dirname}_ner_train.json")
    dev_path_out = os.path.join(full_out_dir, f"{out_dirname}_ner_dev.json")
    eval_path_out = os.path.join(full_out_dir, f"{out_dirname}_ner_eval.json")

    with open(train_path_out, "w", encoding="utf-8") as f:
        json.dump(train_split, f, indent=2, ensure_ascii=False)

    with open(dev_path_out, "w", encoding="utf-8") as f:
        json.dump(dev_split, f, indent=2, ensure_ascii=False)

    with open(eval_path_out, "w", encoding="utf-8") as f:
        json.dump(eval_split, f, indent=2, ensure_ascii=False)

    # numbers shown are about documents and not spans
    print(
        f"Saved: train={len(train_split)} dev={len(dev_split)} eval={len(eval_split)} "
        f"(total={n}, eval_ratio~={len(eval_split)/n:.3f}) -> {full_out_dir}"
    )
# Out:
# Processing category: Unsupported claim
# Saved: train=199 dev=24 eval=26 (total=249, eval_ratio~=0.104) -> data/unsupported_claim
# Processing category: Lacks synthesis
# Saved: train=220 dev=27 eval=29 (total=276, eval_ratio~=0.105) -> data/lacks_synthesis
# Processing category: Coherence
# Saved: train=239 dev=29 eval=31 (total=299, eval_ratio~=0.104) -> data/coherence
# Processing category: Format
# Saved: train=236 dev=29 eval=30 (total=295, eval_ratio~=0.102) -> data/format
